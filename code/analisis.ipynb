# %%
import functions
print(functions.__file__)
# %reload_ext autoreload
# %autoreload 2
# Out:
# /Users/maceli/ifood_cs/code/functions.py

# %%
import importlib, functions
importlib.reload(functions)
import pandas as pd
from functions import load_data, check_key_uniqueness,join_group_count,join_group_count_with_nulls,matriz_migracao,resumo_coorte_ativa, process_orders_pandas

# %%
df_consumer = pd.read_parquet("data_output/df_consumer.parquet")
df_consumer.head()
# Out:
#                                          customer_id  active  \
# 0  e8cc60860e09c0bb19610b06ced69c973eb83982cfc98e...    True
# 1  a2834a38a9876cf74e016524dd2e8c1f010ee12b2b684d...    True
# 2  41e1051728eba13341136d67d0757f8d8cc44b2a405b71...    True
# 3  8e7c1dcb64edf95c935147f6d560cb068c44714cb1b21b...    True
# 4  7823d4cf4150c5daeae0bd799206852fc123bdef0cf5d1...    True
#
#                  created_at
# 0  2018-04-05T14:49:18.165Z
# 1  2018-01-14T21:40:02.141Z
# 2  2018-01-07T03:47:15.554Z
# 3  2018-01-10T22:17:08.160Z
# 4  2018-04-06T00:16:20.935Z

# %%
df_publico_copy=df_publico.copy

# %%
df_publico = pd.read_parquet("data_output/df_con_or.parquet")
df_publico.head()
# Out:
#                                          customer_id is_target  active  \
# 0  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control    True
# 1  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control    True
# 2  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control    True
# 3  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control    True
# 4  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control    True
#
#                  created_at  \
# 0  2018-04-06T00:05:23.543Z
# 1  2018-04-06T00:05:23.543Z
# 2  2018-04-06T00:05:23.543Z
# 3  2018-04-06T00:05:23.543Z
# 4  2018-04-06T00:05:23.543Z
#
#                                          merchant_id  \
# 0  75168a16437068a463d8c825e7c4638128a028f1745245...
# 1  f6b76403a124780d6fc242de3d9c398eec9b436d769b3f...
# 2  f6b76403a124780d6fc242de3d9c398eec9b436d769b3f...
# 3  ab0ecc0f539748be384ff8456b251224ede4f833c8058f...
# 4  659a196ad800c788115707631267ee6a232915cb855180...
#
#            order_created_at  \
# 0  2019-01-01T20:31:38.000Z
# 1  2019-01-25T23:26:38.000Z
# 2  2019-01-16T01:31:20.000Z
# 3  2019-01-10T15:37:46.000Z
# 4  2019-01-25T14:57:46.000Z
#
#                                             order_id  order_total_amount  \
# 0  c623211eb5dda070416069c51f36e4370260e94ee6a45e...                28.5
# 1  0b6b7456c4bf57f56f97c752b1d500e8ad5b3f535494b8...                30.4
# 2  a31b414ef2936435ed56b98107d714c8f2819a82fcb782...                31.4
# 3  b83be3a923ab36e459500fdb5f2afb3ffa887429bb1cbf...                24.9
# 4  a6469ab902d0da5d6a258cc6ca1c805dd6b166148ae402...                24.0
#
#   ingestion_date
# 0     2025-11-14
# 1     2025-11-14
# 2     2025-11-14
# 3     2025-11-14
# 4     2025-11-14

# %%
df_final, df_percent=process_orders_pandas(df_publico)

# %%
df_final.head()
# Out:
#                                                customer_id is_target  active  \
# 3661049  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target    True
# 3661048  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target    True
# 3661047  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target    True
# 3661046  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target    True
# 3661045  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target    True
#
#                        created_at  \
# 3661049  2018-03-18T20:13:36.598Z
# 3661048  2018-03-18T20:13:36.598Z
# 3661047  2018-01-06T21:14:22.216Z
# 3661046  2018-01-06T21:14:22.216Z
# 3661045  2018-01-06T21:14:22.216Z
#
#                                                merchant_id  \
# 3661049  75ad88804dcd055f654e9f4539d5e2b290f2e0c179fdea...
# 3661048  75ad88804dcd055f654e9f4539d5e2b290f2e0c179fdea...
# 3661047  79c7e1e515b1ca71f120ec3f8e766b7e11d1fec3e7b767...
# 3661046  79c7e1e515b1ca71f120ec3f8e766b7e11d1fec3e7b767...
# 3661045  79c7e1e515b1ca71f120ec3f8e766b7e11d1fec3e7b767...
#
#                  order_created_at  order_total_amount ingestion_date  \
# 3661049 2018-12-31 23:42:55+00:00               167.0     2025-11-14
# 3661048 2019-01-30 23:42:55+00:00               167.0     2025-11-14
# 3661047 2018-12-08 22:02:52+00:00               150.0     2025-11-14
# 3661046 2018-12-17 22:53:55+00:00                59.0     2025-11-14
# 3661045 2019-01-07 22:02:52+00:00               150.0     2025-11-14
#
#                                          unique_order_hash  \
# 3661049  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...
# 3661048  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...
# 3661047  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...
# 3661046  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...
# 3661045  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...
#
#          order_created_month  total_amount_mes  ticket_medio  num_pedidos_mes  \
# 3661049                   12             167.0         167.0                1
# 3661048                    1             167.0         167.0                1
# 3661047                   12             209.0         104.5                2
# 3661046                   12             209.0         104.5                2
# 3661045                    1             209.0         104.5                2
#
#          num_pedidos_hist           prev_order_time  diff_days
# 3661049                 2                       NaT        NaN
# 3661048                 2 2018-12-31 23:42:55+00:00       30.0
# 3661047                 4                       NaT        NaN
# 3661046                 4 2018-12-08 22:02:52+00:00        9.0
# 3661045                 4 2018-12-17 22:53:55+00:00       20.0

# %%
distinct_df = df_final[["customer_id","is_target", "order_created_month", "num_pedidos_mes", "num_pedidos_hist",'total_amount_mes','ticket_medio']].drop_duplicates().reset_index(drop=True)
distinct_df
# Out:
#                                                customer_id is_target  \
# 0        ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 1        ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 2        ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 3        ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 4        ffffe50aaaed54af0eb463fcc6761b0e17a1d1cdd6b8e1...   control
# ...                                                    ...       ...
# 1360527  000022ced2f3aa411b66ac41167b272ae528c4acdffeeb...    target
# 1360528  000021924bf8192f64a7cc17ce7c0bc511cba907308f80...    target
# 1360529  000021924bf8192f64a7cc17ce7c0bc511cba907308f80...    target
# 1360530  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control
# 1360531  000009e29b12d8c5b9c9579e21384320c2df3bd935f19e...   control
#
#          order_created_month  num_pedidos_mes  num_pedidos_hist  \
# 0                         12                1                 2
# 1                          1                1                 2
# 2                         12                2                 4
# 3                          1                2                 4
# 4                         12                1                 2
# ...                      ...              ...               ...
# 1360527                    1                2                 4
# 1360528                   12                2                 5
# 1360529                    1                3                 5
# 1360530                   12                2                10
# 1360531                    1                8                10
#
#          total_amount_mes  ticket_medio
# 0                  167.00    167.000000
# 1                  167.00    167.000000
# 2                  209.00    104.500000
# 3                  209.00    104.500000
# 4                   55.60     55.600000
# ...                   ...           ...
# 1360527             68.65     34.325000
# 1360528            119.90     59.950000
# 1360529            173.90     57.966667
# 1360530            100.00     50.000000
# 1360531            273.00     34.125000
#
# [1360532 rows x 7 columns]

# %%
df_excluded = distinct_df[distinct_df['customer_id'].isin(id)].reset_index(drop=True)

# %%
distinct_df.head()
# Out:
#                                          customer_id is_target  \
# 0  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 1  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 2  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 3  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 4  ffffe50aaaed54af0eb463fcc6761b0e17a1d1cdd6b8e1...   control
#
#    order_created_month  num_pedidos_mes  num_pedidos_hist  total_amount_mes  \
# 0                   12                1                 2             167.0
# 1                    1                1                 2             167.0
# 2                   12                2                 4             209.0
# 3                    1                2                 4             209.0
# 4                   12                1                 2              55.6
#
#    ticket_medio
# 0         167.0
# 1         167.0
# 2         104.5
# 3         104.5
# 4          55.6

# %% [markdown]
# Matrix de migracao de clientes

# %%
matriz_migracao(distinct_df,mes_0=12,mes_1=1)
# Out:
#    mes_12  mes_1 is_target  total_clientes
# 0       0      1   control          118956
# 1       0      1    target          132824
# 2       1      1   control          241457
# 3       1      1    target          312919

# %% [markdown]
# Dado o numero de 'novo', proceguiremos as analises somente com clientes que tem pedidos em ambos os meses

# %%
id_both_monht=distinct_df[distinct_df['order_created_month']==12]['customer_id'].unique()
distinct_df_bt = distinct_df[distinct_df['customer_id'].isin(id_both_monht)].reset_index(drop=True)
len(id_both_monht)
# Out:
# 554376

# %%
distinct_df_bt.head(20)
# Out:
#                                           customer_id is_target  \
# 0   ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 1   ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 2   ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 3   ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 4   ffffe50aaaed54af0eb463fcc6761b0e17a1d1cdd6b8e1...   control
# 5   ffffe50aaaed54af0eb463fcc6761b0e17a1d1cdd6b8e1...   control
# 6   ffffdfae8a70b042a8f86763f59024f61899d6f30dec60...    target
# 7   ffffdfae8a70b042a8f86763f59024f61899d6f30dec60...    target
# 8   ffffd512938c9c6a7fc101b6bc044c2bc542505ceff2a5...   control
# 9   ffffd512938c9c6a7fc101b6bc044c2bc542505ceff2a5...   control
# 10  ffffb914ed2fc2abf0763d8ffeb2a6f6a4149d48b71897...    target
# 11  ffffb914ed2fc2abf0763d8ffeb2a6f6a4149d48b71897...    target
# 12  ffffb54b6362e4b0eb7f22ca3695fbd1c14865e0d4b42d...    target
# 13  ffffb54b6362e4b0eb7f22ca3695fbd1c14865e0d4b42d...    target
# 14  ffff99ee36f50a3139d21acffc30239698e6e3d83d0824...    target
# 15  ffff99ee36f50a3139d21acffc30239698e6e3d83d0824...    target
# 16  ffff85c4468857f1f74a9ecc7f558bb64b9a6cb1f88dfc...    target
# 17  ffff85c4468857f1f74a9ecc7f558bb64b9a6cb1f88dfc...    target
# 18  ffff5347ec344619920c4ff44449dfd1a34e41c24bd77d...   control
# 19  ffff5347ec344619920c4ff44449dfd1a34e41c24bd77d...   control
#
#     order_created_month  num_pedidos_mes  num_pedidos_hist  total_amount_mes  \
# 0                    12                1                 2            167.00
# 1                     1                1                 2            167.00
# 2                    12                2                 4            209.00
# 3                     1                2                 4            209.00
# 4                    12                1                 2             55.60
# 5                     1                1                 2             55.60
# 6                    12                1                 2             22.80
# 7                     1                1                 2             22.80
# 8                    12                2                 8             53.30
# 9                     1                6                 8            187.40
# 10                   12                5                13             97.00
# 11                    1                8                13            170.00
# 12                   12                1                 3              9.00
# 13                    1                2                 3             19.00
# 14                   12                1                 5             40.98
# 15                    1                4                 5            173.24
# 16                   12                1                 2             39.90
# 17                    1                1                 2             39.90
# 18                   12                7                20            232.52
# 19                    1               13                20            562.02
#
#     ticket_medio
# 0     167.000000
# 1     167.000000
# 2     104.500000
# 3     104.500000
# 4      55.600000
# 5      55.600000
# 6      22.800000
# 7      22.800000
# 8      26.650000
# 9      31.233333
# 10     19.400000
# 11     21.250000
# 12      9.000000
# 13      9.500000
# 14     40.980000
# 15     43.310000
# 16     39.900000
# 17     39.900000
# 18     33.217143
# 19     43.232308

# %%
pedidos_hist=resumo_coorte_ativa(distinct_df_bt,12)

# %%
pedidos_hist.head()
# Out:
#   is_target  Total_Pedidos_Janeiro  Total_Pedidos_Dezembro  Total_Clientes
# 0   control                      1                       1           97595
# 1   control                      2                       1           22495
# 2   control                      2                       2           19972
# 3   control                      3                       1           10227
# 4   control                      3                       2            9732

# %%
df_resumo_por_pedidos.to_csv('pedidos_hist.csv')

# %%
distinct_df_bt.columns
# Out:
# Index(['customer_id', 'is_target', 'order_created_month', 'num_pedidos_mes',
#        'num_pedidos_hist', 'total_amount_mes', 'ticket_medio'],
#       dtype='object')

# %%
df_janeiro.head()
# Out:
#                                          customer_id is_target  \
# 1  ffffeda85b466b48195c356f8b97f21d0b23958d5815fc...    target
# 3  ffffe95dc11472a22c46b6d5cdc5c14cf40e0c88a601e0...    target
# 5  ffffe50aaaed54af0eb463fcc6761b0e17a1d1cdd6b8e1...   control
# 7  ffffdfae8a70b042a8f86763f59024f61899d6f30dec60...    target
# 9  ffffd512938c9c6a7fc101b6bc044c2bc542505ceff2a5...   control
#
#    order_created_month  num_pedidos_mes  num_pedidos_hist  total_amount_mes  \
# 1                    1                1                 2             167.0
# 3                    1                2                 4             209.0
# 5                    1                1                 2              55.6
# 7                    1                1                 2              22.8
# 9                    1                6                 8             187.4
#
#    ticket_medio
# 1    167.000000
# 3    104.500000
# 5     55.600000
# 7     22.800000
# 9     31.233333

# %%
df_janeiro=distinct_df_bt[distinct_df_bt['order_created_month']==1]

# %%
import pandas as pd
import numpy as np
from scipy import stats 

def calcular_lift_generico(df_analise: pd.DataFrame, coluna_metrica: str) -> dict:
    """
    Calcula o Lift (ganho percentual) e a Significância Estatística (P-valor) 
    para uma métrica contínua em um teste A/B, usando 'control' e 'target' como rótulos.

    Args:
        df_analise (pd.DataFrame): DataFrame da coorte, contendo uma linha por cliente, 
                                   com as colunas 'is_target' e a métrica de interesse.
        coluna_metrica (str): Nome da coluna com os valores agregados (e.g., 'total_amount_mes').

    Returns:
        dict: Dicionário com médias, Lift, P-valor e status de significância.
    """
    
    # 1. Calcula as médias da métrica por grupo
    medias = df_analise.groupby('is_target')[coluna_metrica].mean()
    
    try:
        avg_controle = medias.loc['control']
        avg_teste = medias.loc['target']
    except KeyError as e:
        return {"Erro": f"Grupos 'control' ou 'target' ausentes: {e}. Verifique a coluna 'is_target'."}
    
    # 2. Cálculo do Lift (Teste / Controle - 1)
    lift = (avg_teste / avg_controle) - 1 if avg_controle > 0 else np.nan
    
    # 3. Prepara dados para o Teste t
    data_controle = df_analise[df_analise['is_target'] == 'control'][coluna_metrica]
    data_teste = df_analise[df_analise['is_target'] == 'target'][coluna_metrica]
    
    # Teste t de Student para duas amostras (Welch's t-test, unilateral: Teste > Controle)
    t_stat, p_value = stats.ttest_ind(data_teste, data_controle, equal_var=False, alternative='greater')

    return {
        "Metrica": coluna_metrica,
        "Media_Controle": avg_controle,
        "Media_Teste": avg_teste,
        "Lift": lift,
        "P_Value": p_value,
        "Significativo_05": p_value < 0.05
    }

resultado_amount = calcular_lift_generico(df_janeiro, 'total_amount_mes')

print("--- Resultado do Lift de Amount Total (Valor) ---")
print(f"Média Controle: R$ {resultado_amount['Media_Controle']:.2f}")
print(f"Média Teste:    R$ {resultado_amount['Media_Teste']:.2f}")
print(f"Lift:           {resultado_amount['Lift']:.2%}")
print(f"P-Valor:        {resultado_amount['P_Value']:.4f}")
print(f"Significativo:  {resultado_amount['Significativo_05']}")

###print("--- Resultado do Lift de Frequência (Pedidos) ---")
#print(f"Lift: {resultado_frequencia['Lift']:.2%}")
#print(f"P-Valor: {resultado_frequencia['P_Value']:.4f}")
#print(f"Significativo: {resultado_frequencia['Significativo_05']}")
# Out:
# --- Resultado do Lift de Amount Total (Valor) ---
# Média Controle: R$ 168.02
# Média Teste:    R$ 185.91
# Lift:           10.65%
# P-Valor:        0.0000
# Significativo:  True

# %%
resultado_frequencia = calcular_lift_generico(df_janeiro, 'num_pedidos_mes')

print("--- Resultado do Lift de Frequência (Pedidos) ---")
print(f"Lift: {resultado_frequencia['Lift']:.2%}")
print(f"P-Valor: {resultado_frequencia['P_Value']:.4f}")
print(f"Significativo: {resultado_frequencia['Significativo_05']}")
# Out:
# --- Resultado do Lift de Frequência (Pedidos) ---
# Lift: 10.91%
# P-Valor: 0.0000
# Significativo: True
