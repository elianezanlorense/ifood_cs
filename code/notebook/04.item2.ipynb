# %%
import sys
import os
sys.path.append('..')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

import utilities.functions as functions
from utilities.functions import (
    retidos,
    calcula_viabilidade,
    analisar_retencao
)
from pathlib import Path
BASE_PATH = Path("/Users/maceli/ifood_cs/dados")

# %%
df = pd.read_parquet(BASE_PATH / "gold" / "publico_janeiro_dezembro.parquet")
df.head()

# %%
df['seg'] = 0
df.loc[df['num_pedidos_mes'] == 1, 'seg'] = 1
df.loc[(df['num_pedidos_mes'] > 1) & (df['num_pedidos_mes'] <= 10), 'seg'] = 3
df.loc[df['num_pedidos_mes'] > 10, 'seg'] = 2

# %%
analise_completa = (
    df.groupby(['is_target','order_created_month','seg'])
    .agg(
        customer_count=('customer_id', 'nunique')
    )
    .reset_index()
)
analise_completa.head()

# %%
df_base_final = None
todos_resumos = []
for i in df['seg'].unique():
    print(i)
    df_filter = df[df['seg'] == i]
    resultados = calcula_viabilidade(df_filter, mes_campanha=12, mes_seguinte=1, coupon_value=10.0, margin_rate=0.12)
    resultados['seg'] = i
    df_base_final = pd.concat([df_base_final, resultados])
# Out:
# 2
# 3
# 1

# %%
df_base_final
# Out:
#    mes_campanha  mes_seguinte  coupon_value  margin_rate  clientes_target_dec  \
# 0            12             1          10.0         0.12                    5
# 0            12             1          10.0         0.12                   32
# 0            12             1          10.0         0.12                   10
#
#    clientes_control_dec  clientes_target_jan  clientes_control_jan  \
# 0                     3                   15                    12
# 0                    23                   34                    23
# 0                     9                    8                     8
#
#    base_target_dec  pedidos_tot_target_dec  ...  margem_incremental_dec  \
# 0                5                      68  ...                138.3084
# 0               32                     132  ...                 30.1344
# 0               10                      10  ...                 29.7948
#
#    margem_incremental_jan  margem_incremental_total  custo_campanha  \
# 0               -249.2484                 -110.9400            50.0
# 0                547.6176                  577.7520           320.0
# 0                 11.9160                   41.7108           100.0
#
#    dezembro_pos  lucro_incremental       roi  gmv_total_target  \
# 0      258.0340          -160.9400 -3.218800          11150.09
# 0      358.8784           257.7520  0.805475          14768.45
# 0      -24.8560           -58.2892 -0.582892            970.70
#
#    gmv_total_control  seg
# 0           12074.59    2
# 0            9953.85    3
# 0             623.11    1
#
# [3 rows x 47 columns]
